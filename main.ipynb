# %%
import torch
import torch.nn as nn

model = nn.Sequential(
    nn.Linear(5, 4),
    nn.ReLU(), # max(0,x)

    nn.Linear(4, 4),
    nn.ReLU(),

    nn.Linear(4, 4),
    nn.ReLU(),

    nn.Linear(4, 1),
)

model.load_state_dict(
    torch.load("bevoelkerungsstand_model.pth", weights_only=True)
)

# %%
years = [
    # <-- add 5 years here
]

# %%
input = torch.tensor(
    [years],
    dtype=torch.float32
)

with torch.no_grad():
    prediction = model(input)

print(prediction.item())
